# %% [markdown]
# # 🛠️ Feature Engineering
# ### Behavioral, Temporal, Velocity, and Risk Features

# %%
import sys
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from src.feature_engineering import engineer_features, build_feature_context

parquet_path = PROJECT_ROOT / "data" / "merged" / "mapped_common_schema.parquet"
df = pd.read_parquet(parquet_path).head(10000)
print("Raw columns:", list(df.columns))
# Out:
# Raw columns: ['transaction_id', 'timestamp', 'amount', 'sender_id', 'receiver_id', 'device_type', 'merchant_category', 'location', 'transaction_type', 'fraud_label']

# %% [markdown]
# ## Engineer Features

# %%
engineered_df = engineer_features(df)
print("Engineered columns:", list(engineered_df.columns))
print("Engineered shape:", engineered_df.shape)
engineered_df[["amount", "hour_of_day", "is_weekend", "transactions_per_hour", "amount_spike", "unusual_transaction_timing"]].head()
# Out:
# 2026-08-22 17:43:17,828 | INFO | src.feature_engineering | Starting feature engineering on 10000 rows
# 2026-08-22 17:43:17,834 | INFO | src.feature_engineering | Adding temporal features
# 2026-08-22 17:43:17,835 | INFO | src.feature_engineering | Adding behavioral features
# 2026-08-22 17:43:17,840 | INFO | src.feature_engineering | Adding velocity features
# 2026-08-22 17:43:17,843 | INFO | src.feature_engineering | Adding risk features
# 2026-08-22 17:43:17,844 | INFO | src.feature_engineering | Calculating usual location per sender
# 2026-08-22 17:43:17,848 | INFO | src.feature_engineering | Feature engineering complete with 25 columns
# ...
