# %% [markdown]
# # 🔍 Unsupervised Anomaly Detection
# ### Isolation Forest & Local Outlier Factor (LOF)

# %%
import sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

scores_path = PROJECT_ROOT / "data" / "processed" / "isolation_forest_anomaly_scores.csv"
if scores_path.exists():
    df_scores = pd.read_csv(scores_path)
    print("Isolation Forest Anomaly Scores Loaded:", df_scores.shape)
    print(df_scores["anomaly_label"].value_counts())
    df_scores.head()
else:
    print("Anomaly scores file not found.")
# Out:
# Isolation Forest Anomaly Scores Loaded: (200000, 4)
# anomaly_label
# Normal     190000
# Anomaly     10000
# Name: count, dtype: int64
